# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals=[1400,600,300,410,250]
exp_labels=['Home rents','Food','Phone/Internet bill', 'Car','Other utilisation']

# %%
plt.pie(exp_vals,labels=exp_labels,autopct='%0.1f%%',shadow="True",explode=[0,0.02,0,0,0])
plt.show()

# %%
plt.axis("equal")
# Out:
# (np.float64(-0.05500000000000001),
#  np.float64(0.05500000000000001),
#  np.float64(-0.05500000000000001),
#  np.float64(0.05500000000000001))
